# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/dazedinthecity/Documents/GitHub/CEU-DMDB-GroupH/data/private/to_be_implemented.csv')
df['Department'] = df['Department'].str.strip()
unique_departments = df['Department'].unique()

# %%
unique_departments.dtype

# %% [markdown]
# ### making the csv for populating db

# %%
import csv

with open("output.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(my_list)  # writes as a single row

# %%
import os

output_path = os.path.join("path", "to", "folder", "output.csv")
with open(output_path, "w", newline="") as f:

# %%
import csv
import os

my_list = unique_departments.tolist()  # convert numpy array to list

output_path = os.path.join("/Users/dazedinthecity/Documents/GitHub/CEU-DMDB-GroupH/data/private", "output.csv")
with open(output_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["department_id", "department_name"])  # header row
    for i, name in enumerate(my_list, start=1):
        writer.writerow([i, name])
