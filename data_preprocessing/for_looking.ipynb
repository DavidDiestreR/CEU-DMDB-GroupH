# %%
import pandas as pd
df = pd.read_csv('/Users/dazedinthecity/Documents/GitHub/CEU-DMDB-GroupH/data/private/cleaned_data.csv')

# %%
cor_pro = df['Corresponding_collections'].tolist()

# %%
cor_pro
