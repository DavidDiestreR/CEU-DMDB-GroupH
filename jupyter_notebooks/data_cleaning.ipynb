# %% [markdown]
# # Jupyter Notebook to clean data.xlsx

# %%
import pandas as pd

# %% [markdown]
# ## Exploring the dataset

# %%
# replace with your Excel file path
file_path = "/Users/dazedinthecity/Documents/GitHub/CEU-DMDB-GroupH/data/private/data.xlsx"

# read first sheet into DataFrame
df = pd.read_excel(file_path, sheet_name=0)

# quick check
df.shape
# Out:
# (1846, 99)

# %%
# replace with your Excel file path
file_path_TE = "/Users/dazedinthecity/Desktop/Databases/TE_Course_Data_25-26.csv"

# read first sheet into DataFrame
df_TE = pd.read_csv(file_path_TE)

# quick check
df_TE.shape
# Out:
# (83, 93)

# %%
df_TE.head()
# Out:
#   Offering periods Course code  \
# 0              NaN    POLS5773
# 1      Winter term    DNDS5013
# 2      Spring term    DNDS9101
# 3              NaN    ECBS5334
# 4              NaN    ENVS5234
#
#                                                Title  \
# 0                         Quantitative Text Analysis
# 1                                 Thesis Preparation
# 2                                     Thesis Project
# 3  Data Engineering 4: AI Engineering - Integrati...
# 4          EO: Earth Observations in Monitoring SDGs
#
#                             Program (course owner)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3  (MSBAIP1F) MS in Business Analytics (full time)
# 4                                              NaN
#
#                                           Department  Offered Taught  \
# 0             (POLS) Department of Political Science    False    Yes
# 1      (DNDS) Department of Network and Data Science     True     No
# 2      (DNDS) Department of Network and Data Science     True     No
# 3                     (ECBS) Department of Economics    False    Yes
# 4  (ENVS) Department of Environmental Sciences an...    False    Yes
#
#    US credits  ECTS                 Level  ... is required by  \
# 0         2.0   4.0  Master or equivalent  ...            NaN
# 1         2.0   4.0  Master or equivalent  ...            NaN
# 2         6.0  12.0  Master or equivalent  ...            NaN
# 3         1.0   2.0  Master or equivalent  ...            NaN
# 4         2.0   4.0  Master or equivalent  ...            NaN
#
#                                             requires Load division (count)  \
# 0                                                NaN                     0
# 1                                                NaN                     0
# 2                                                NaN                     0
# 3  (ECBS5146) Data Engineering 1: Cloud Computing...                     0
# 4  (ENVS5238) GST: Geospatial Technologies for En...                     0
#
#   Load division New course Manage course basics Course late changes  \
# 0           NaN        NaN             Approved                 NaN
# 1           NaN        NaN             Approved                 NaN
# 2           NaN        NaN             Approved                 NaN
# 3           NaN        NaN             Approved      Change applied
# 4           NaN        NaN             Approved                 NaN
#
#   Course details  Course detail late changes  Instructor (changes)
# 0       Approved                         NaN                 False
# 1            NaN                         NaN                 False
# 2            NaN                         NaN                 False
# 3       Approved                         NaN                 False
# 4       Maintain                         NaN                 False
#
# [5 rows x 93 columns]

# %% [markdown]
# ## Dealing with NAs

# %%
# Missing-value summaries for df_TE
# per-column missing counts and percent
missing_col_TE = df_TE.isna().sum()
missing_col_pct_TE = (df_TE.isna().mean() * 100).round(2)
missing_col_TE_df = pd.DataFrame({'missing_count': missing_col_TE, 'missing_pct': missing_col_pct_TE})

display(missing_col_TE_df.sort_values('missing_count', ascending=False))

# per-row missing counts and percent (show top rows with most missing values)
missing_row_TE = df_TE.isna().sum(axis=1)
missing_row_pct_TE = (df_TE.isna().mean(axis=1) * 100).round(2)
missing_row_TE_df = pd.DataFrame({'missing_count': missing_row_TE, 'missing_pct': missing_row_pct_TE})

display(missing_row_TE_df.sort_values('missing_count', ascending=False).head(20))

# quick totals
print('Rows with any missing values (df_TE):', df_TE.isna().any(axis=1).sum())
print('Total cells (df_TE):', df_TE.size)
print('Total missing cells (df_TE):', df_TE.isna().sum().sum())
# Out:
#                          missing_count  missing_pct
# Minimum                             83        100.0
# Assessments                         83        100.0
# Resources                           83        100.0
# Optimum                             83        100.0
# Diet/collection phases              83        100.0
# ...                                ...          ...
# Course occurence (diff)              0          0.0
# Temporary course code                0          0.0
# Course code                          0          0.0
# Marking scheme                       0          0.0
# Instructor (changes)                 0          0.0
#
# [93 rows x 2 columns]
#     missing_count  missing_pct
# 6              61        65.59
# 7              61        65.59
# 8              60        64.52
# 1              58        62.37
# 2              57        61.29
# 54             53        56.99
# 35             52        55.91
# 36             50        53.76
# 12             49        52.69
# 0              49        52.69
# 22             48        51.61
# 40             46        49.46
# 81             46        49.46
# 42             46        49.46
# 4              46        49.46
# 31             45        48.39
# 46             45        48.39
# 59             45        48.39
# 11             44        47.31
# 37             44        47.31
# Rows with any missing values (df_TE): 83
# Total cells (df_TE): 7719
# Total missing cells (df_TE): 3612

# %%
# per-column missing counts and percent
missing_col = df.isna().sum()
missing_col_pct = (df.isna().mean() * 100).round(2)
missing_col_df = pd.DataFrame({'missing_count': missing_col, 'missing_pct': missing_col_pct})

display(missing_col_df.sort_values('missing_count', ascending=False))

# per-row missing counts and percent (show top rows with most missing values)
missing_row = df.isna().sum(axis=1)
missing_row_pct = (df.isna().mean(axis=1) * 100).round(2)
missing_row_df = pd.DataFrame({'missing_count': missing_row, 'missing_pct': missing_row_pct})

display(missing_row_df.sort_values('missing_count', ascending=False).head(20))

# quick totals
print('Rows with any missing values:', df.isna().any(axis=1).sum())
print('Total cells:', df.size)
print('Total missing cells:', df.isna().sum().sum())
# Out:
#                                                     missing_count  missing_pct
# Instructor                                                    909        49.24
# Course late changes (Winter term)                             804        43.55
# Corresponding programs                                        644        34.89
# Corresponding program codes                                   644        34.89
# Offering periods                                              570        30.88
# Corresponding diet/collections                                503        27.25
# Corresponding diet/collections codes                          503        27.25
# Course details                                                502        27.19
# Course detail late changes                                    469        25.41
# Assessment type                                               398        21.56
# Abbreviation                                                  393        21.29
# Import date                                                   391        21.18
# Temporary course code                                         386        20.91
# External ID                                                   382        20.69
# Offered for non-degree students                               310        16.79
# Offered                                                        99         5.36
# Allow repeats                                                  91         4.93
# Course occurence                                               75         4.06
# Course occurence (diff)                                        75         4.06
# Course occurence (code)                                        75         4.06
# Publication date                                               28         1.52
# US credits                                                     14         0.76
# ECTS                                                            7         0.38
# Course type                                                     6         0.33
# Manage course basics                                            6         0.33
# Level                                                           3         0.16
# Taught                                                          3         0.16
# Scheme                                                          2         0.11
# Course code                                                     2         0.11
# Marking scheme                                                  2         0.11
# Title                                                           0         0.00
# Changes in Learning outcomes (EN)                               0         0.00
# Changes in Learning activities and teaching met...              0         0.00
# Changes in Assessment (EN)                                      0         0.00
# Changes in Course contents (EN)                                 0         0.00
# Changes in Background and overall aim (EN)                      0         0.00
# Changes in Contact details (EN)                                 0         0.00
# Changes in Course prerequisites (EN)                            0         0.00
# Changes in Waiting list handling (EN)                           0         0.00
# Load division (count)                                           0         0.00
# Ignore in TE Curriculum                                         0         0.00
# Terminated                                                      0         0.00
# Department                                                      0         0.00
# UID                                                             0         0.00
# Instructor (changes)                                            0         0.00
#       missing_count  missing_pct
# 1845             26        57.78
# 1844             26        57.78
# 1840             18        40.00
# 1824             17        37.78
# 1547             15        33.33
# 1556             15        33.33
# 1831             15        33.33
# 1558             14        31.11
# 1551             14        31.11
# 1552             14        31.11
# 1553             14        31.11
# 1554             14        31.11
# 1555             14        31.11
# 1557             14        31.11
# 1559             14        31.11
# 1549             14        31.11
# 1561             14        31.11
# 1562             14        31.11
# 1563             14        31.11
# 1564             14        31.11
# Rows with any missing values: 1446
# Total cells: 83070
# Total missing cells: 8296

# %%
# Drop columns with >=50% missing values for both df and df_TE
thresh = 50.0

# For df
missing_col_pct = (df.isna().mean() * 100).round(2)
cols_to_drop_df = missing_col_pct[missing_col_pct >= thresh].index.tolist()
print('Columns to drop from df (>=50% missing):', cols_to_drop_df)
if cols_to_drop_df:
    df.drop(columns=cols_to_drop_df, inplace=True)
print('df shape after drop:', df.shape)

# For df_TE
missing_col_pct_TE = (df_TE.isna().mean() * 100).round(2)
cols_to_drop_df_TE = missing_col_pct_TE[missing_col_pct_TE >= thresh].index.tolist()
print('Columns to drop from df_TE (>=50% missing):', cols_to_drop_df_TE)
if cols_to_drop_df_TE:
    df_TE.drop(columns=cols_to_drop_df_TE, inplace=True)
print('df_TE shape after drop:', df_TE.shape)
# Out:
# Columns to drop from df (>=50% missing): ['Original code', 'Name', 'Organisation', 'Specification', 'Program (course owner)', 'Contact hours', 'Start date', 'End date', 'Advised periods', 'Diet/collection descriptions', 'Diet/collection phases', 'Resources', 'Subjects', 'Assessments', 'Exams (diff)', 'Exams (activity)', 'Course occurence (activity)', 'CIVICA', 'OSUN', 'Academic writing course', 'Offered only for department(s)', 'Course offered for cross-listing', 'Offered only for program(s)', 'Historic code', 'Historic title', 'Methods course', 'Find your own course', 'Please revive my course', 'Sub type (label)', 'Minimum', 'Optimum', 'Maximum', 'US credits (minimum)', 'US credits (maximum)', 'Learning outcomes (EN)', 'Learning activities and teaching methods (EN)', 'Assessment (EN)', 'Course contents (EN)', 'Background and overall aim (EN)', 'Contact details (EN)', 'Course prerequisites (EN)', 'Waiting list handling (EN)', 'Offering periods remarks', 'Instructor (id)', 'Instructor (email)', 'is excluded by', 'excludes', 'FLW', 'must be followed for', 'requires', 'is required by', 'Course late changes (Spring term)', 'Course late changes', 'New course']
# df shape after drop: (1846, 45)
# Columns to drop from df_TE (>=50% missing): ['Program (course owner)', 'Organisation', 'Specification', 'Start date', 'End date', 'Publication date', 'Import date', 'Advised periods', 'Diet/collection descriptions', 'Diet/collection phases', 'Resources', 'Subjects', 'Assessments', 'Exams (diff)', 'Exams (activity)', 'Course occurence (activity)', 'CIVICA', 'OSUN', 'Academic writing course', 'Offered only for department(s)', 'Offered only for program(s)', 'Historic code', 'Historic title', 'Methods course', 'Find your own course', 'Please revive my course', 'Sub type (label)', 'US credits (minimum)', 'US credits (maximum)', 'Minimum', 'Optimum', 'Maximum', 'Offering periods remarks', 'is excluded by', 'excludes', 'must be followed for', 'FLW', 'is required by', 'requires', 'New course', 'Course late changes', 'Course detail late changes']
# df_TE shape after drop: (83, 51)

# %%
df.head()
# Out:
#   Course code                                             Title  \
# 0    ECBS6011                           Advanced Econometrics 1
# 1    ECBS6255                          Theoretical Econometrics
# 2    GENS5070                      Internship Analysis Workshop
# 3    GENS5119       Academic Writing Part 2: Thesis Development
# 4    GENS5564  Gender and Sexuality in West Asia & North Africa
#
#   Offering periods  Offered Taught Allow repeats  US credits  \
# 0        Fall term      1.0    Yes            No         2.0
# 1        Fall term      1.0    Yes            No         2.0
# 2        Fall term      1.0    Yes            No         2.0
# 3      Winter term      1.0    Yes            No         1.0
# 4        Fall term      1.0    Yes            No         4.0
#
#                              Instructor                   Level  \
# 0           Adam Reiff (reiffa@ceu.edu)  Doctoral or equivalent
# 1           Adam Reiff (reiffa@ceu.edu)  Doctoral or equivalent
# 2  Adriana Qubaiova (qubaiovaa@ceu.edu)    Master or equivalent
# 3  Adriana Qubaiova (qubaiovaa@ceu.edu)    Master or equivalent
# 4  Adriana Qubaiova (qubaiovaa@ceu.edu)    Master or equivalent
#
#                               Corresponding programs  ...  \
# 0  PhD in Economics, MA in Economics, Data, and P...  ...
# 1  MA in Economics, PhD in Economics, MS in Socia...  ...
# 2                      MA in Critical Gender Studies  ...
# 3  MA in Women's and Gender Studies (GEMMA), MA i...  ...
# 4  PhD in Comparative Gender Studies, MA in Natio...  ...
#
#   Changes in Background and overall aim (EN) Changes in Contact details (EN)  \
# 0                                       True                            True
# 1                                       True                            True
# 2                                       True                           False
# 3                                       True                            True
# 4                                       True                            True
#
#   Changes in Course prerequisites (EN) Changes in Waiting list handling (EN)  \
# 0                                 True                                 False
# 1                                 True                                 False
# 2                                False                                 False
# 3                                 True                                 False
# 4                                 True                                 False
#
#   Load division (count) Course late changes (Winter term)  Course details  \
# 0                     1                    Change applied        Maintain
# 1                     1                    Change applied        Maintain
# 2                     1                    Change applied             NaN
# 3                     1                               NaN        Approved
# 4                     1                    Change applied        Approved
#
#    Course detail late changes Manage course basics Instructor (changes)
# 0              Change applied             Approved                False
# 1       Change course details             Approved                False
# 2       Change course details             Approved                 True
# 3              Change applied             Approved                 True
# 4              Change applied             Approved                 True
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Combining the two dataframes

# %%
# Combine `df` and `df_TE` by concatenation (aligns columns automatically)
# show common and unique columns first
common_cols = df.columns.intersection(df_TE.columns).tolist()
only_df = df.columns.difference(df_TE.columns).tolist()
only_df_TE = df_TE.columns.difference(df.columns).tolist()

print('Common columns:', common_cols)
print('Columns only in df:', only_df)
print('Columns only in df_TE:', only_df_TE)

# Concatenate (outer alignment of columns)
combined_df = pd.concat([df, df_TE], ignore_index=True, sort=False)
print('combined_df shape:', combined_df.shape)

# quick peek
combined_df.head()
# Out:
# Common columns: ['Course code', 'Title', 'Offering periods', 'Offered', 'Taught', 'Allow repeats', 'US credits', 'Instructor', 'Level', 'Corresponding programs', 'Course occurence (code)', 'External ID', 'Abbreviation', 'Course type', 'Department', 'Terminated', 'Corresponding diet/collections codes', 'Corresponding diet/collections', 'Corresponding program codes', 'Course occurence', 'Course occurence (diff)', 'Temporary course code', 'Assessment type', 'Marking scheme', 'Offered for non-degree students', 'Scheme', 'ECTS', 'Changes in Learning outcomes (EN)', 'Changes in Learning activities and teaching methods (EN)', 'Changes in Assessment (EN)', 'Changes in Course contents (EN)', 'Changes in Background and overall aim (EN)', 'Changes in Contact details (EN)', 'Changes in Course prerequisites (EN)', 'Changes in Waiting list handling (EN)', 'Load division (count)', 'Course details', 'Manage course basics', 'Instructor (changes)']
# Columns only in df: ['Course detail late changes', 'Course late changes (Winter term)', 'Ignore in TE Curriculum', 'Import date', 'Publication date', 'UID']
# Columns only in df_TE: ['Assessment (EN)', 'Background and overall aim (EN)', 'Contact details (EN)', 'Course contents (EN)', 'Course offered for cross-listing', 'Course prerequisites (EN)', 'Instructor (email)', 'Instructor (id)', 'Learning activities and teaching methods (EN)', 'Learning outcomes (EN)', 'Load division', 'Waiting list handling (EN)']
# combined_df shape: (1929, 57)
#   Course code                                             Title  \
# 0    ECBS6011                           Advanced Econometrics 1
# 1    ECBS6255                          Theoretical Econometrics
# 2    GENS5070                      Internship Analysis Workshop
# 3    GENS5119       Academic Writing Part 2: Thesis Development
# 4    GENS5564  Gender and Sexuality in West Asia & North Africa
#
#   Offering periods  Offered Taught Allow repeats  US credits  \
# 0        Fall term      1.0    Yes            No         2.0
# 1        Fall term      1.0    Yes            No         2.0
# 2        Fall term      1.0    Yes            No         2.0
# 3      Winter term      1.0    Yes            No         1.0
# 4        Fall term      1.0    Yes            No         4.0
#
#                              Instructor                   Level  \
# 0           Adam Reiff (reiffa@ceu.edu)  Doctoral or equivalent
# 1           Adam Reiff (reiffa@ceu.edu)  Doctoral or equivalent
# 2  Adriana Qubaiova (qubaiovaa@ceu.edu)    Master or equivalent
# 3  Adriana Qubaiova (qubaiovaa@ceu.edu)    Master or equivalent
# 4  Adriana Qubaiova (qubaiovaa@ceu.edu)    Master or equivalent
#
#                               Corresponding programs  ...  \
# 0  PhD in Economics, MA in Economics, Data, and P...  ...
# 1  MA in Economics, PhD in Economics, MS in Socia...  ...
# 2                      MA in Critical Gender Studies  ...
# 3  MA in Women's and Gender Studies (GEMMA), MA i...  ...
# 4  PhD in Comparative Gender Studies, MA in Natio...  ...
#
#   Learning outcomes (EN) Learning activities and teaching methods (EN)  \
# 0                    NaN                                           NaN
# 1                    NaN                                           NaN
# 2                    NaN                                           NaN
# 3                    NaN                                           NaN
# 4                    NaN                                           NaN
#
#   Course contents (EN) Assessment (EN) Contact details (EN)  \
# 0                  NaN             NaN                  NaN
# 1                  NaN             NaN                  NaN
# 2                  NaN             NaN                  NaN
# 3                  NaN             NaN                  NaN
# 4                  NaN             NaN                  NaN
#
#   Waiting list handling (EN)  Background and overall aim (EN) Instructor (id)  \
# 0                        NaN                              NaN             NaN
# 1                        NaN                              NaN             NaN
# 2                        NaN                              NaN             NaN
# 3                        NaN                              NaN             NaN
# 4                        NaN                              NaN             NaN
#
#   Instructor (email) Load division
# 0                NaN           NaN
# 1                NaN           NaN
# 2                NaN           NaN
# 3                NaN           NaN
# 4                NaN           NaN
#
# [5 rows x 57 columns]

# %%
df[df['Ignore in TE Curriculum'] == True]
# Out:
# Empty DataFrame
# Columns: [Course code, Title, Offering periods, Offered, Taught, Allow repeats, US credits, Instructor, Level, Corresponding programs, Course occurence (code), UID, External ID, Abbreviation, Course type, Department, Terminated, Ignore in TE Curriculum, Import date, Corresponding diet/collections codes, Corresponding diet/collections, Corresponding program codes, Course occurence, Course occurence (diff), Temporary course code, Publication date, Assessment type, Marking scheme, Offered for non-degree students, Scheme, ECTS, Changes in Learning outcomes (EN), Changes in Learning activities and teaching methods (EN), Changes in Assessment (EN), Changes in Course contents (EN), Changes in Background and overall aim (EN), Changes in Contact details (EN), Changes in Course prerequisites (EN), Changes in Waiting list handling (EN), Load division (count), Course late changes (Winter term), Course details, Course detail late changes, Manage course basics, Instructor (changes)]
# Index: []
#
# [0 rows x 45 columns]

# %%
combined_df.drop(columns=['Ignore in TE Curriculum'], inplace=True)
